# %% [markdown]
# <a href="https://colab.research.google.com/github/sanikaijantakar/ML_Journal/blob/main/RNN_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
from tensorflow.keras.layers import Input


#define the input text and identify unique characters in the text which we’ll encode for our model.

text = "This is GeeksforGeeks a software training institute"
chars = sorted(list(set(text)))
char_to_index = {char: i for i, char in enumerate(chars)}
index_to_char = {i: char for i, char in enumerate(chars)}


#To train the RNN, we need sequences of fixed length (seq_length) and the
#character following each sequence as the label.

seq_length = 4
sequences = []
labels = []

for i in range(len(text) - seq_length):
    seq = text[i:i + seq_length]
    label = text[i + seq_length]
    sequences.append([char_to_index[char] for char in seq])
    labels.append(char_to_index[label])

X = np.array(sequences)
y = np.array(labels)


#For training, we convert X and y into one-hot encoded tensors.
X_one_hot = tf.one_hot(X, len(chars))
y_one_hot = tf.one_hot(y, len(chars))


#We create a simple RNN model with a hidden layer of 50 units and a Dense output
#layer with softmax activation.

model = Sequential()
model.add(Input(shape=(seq_length, len(chars))))  # Define input shape here
model.add(SimpleRNN(50, activation='tanh'))  # No need for input_shape here
model.add(Dense(len(chars), activation='softmax'))


#compile the model using the categorical_crossentropy loss and train it for 100 epochs.

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(X_one_hot, y_one_hot, epochs=100, verbose = 1) #
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.0918 - loss: 2.9462
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.1201 - loss: 2.8766
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.1618 - loss: 2.8220
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.1514 - loss: 2.7725
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.1305 - loss: 2.7439
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.1410 - loss: 2.6915
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2006 - loss: 2.6419
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.2110 - loss: 2.5939
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.2185 - loss: 2.5903
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.3273 - loss: 2.5246
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.3273 - loss: 2.4963
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.3453 - loss: 2.4722
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.3661 - loss: 2.4260
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4012 - loss: 2.3690
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.3841 - loss: 2.3560
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.4153 - loss: 2.3142
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.4229 - loss: 2.2871
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.4750 - loss: 2.1889
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4825 - loss: 2.2076
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4617 - loss: 2.1856
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.4825 - loss: 2.1278
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5137 - loss: 2.0643
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5317 - loss: 2.0582
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5175 - loss: 2.0057
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5317 - loss: 1.9692
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5563 - loss: 1.9410
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5459 - loss: 1.9379
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5355 - loss: 1.9052
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5988 - loss: 1.8778
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6755 - loss: 1.7743
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6585 - loss: 1.7665
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6622 - loss: 1.7408
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7114 - loss: 1.7056
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7531 - loss: 1.6450
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7427 - loss: 1.6060
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7711 - loss: 1.5827
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7711 - loss: 1.5638
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7919 - loss: 1.5011
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7502 - loss: 1.5159
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7890 - loss: 1.4775
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8307 - loss: 1.4110
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8098 - loss: 1.4099
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8098 - loss: 1.3879
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7994 - loss: 1.3376
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8240 - loss: 1.3409
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8553 - loss: 1.2530
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8344 - loss: 1.2475
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8240 - loss: 1.2021
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8344 - loss: 1.1920
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8657 - loss: 1.1187
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8240 - loss: 1.1235
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8590 - loss: 1.1040
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8628 - loss: 1.0927
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8732 - loss: 1.0516
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8732 - loss: 1.0115
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8732 - loss: 0.9954
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8770 - loss: 1.0058
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8770 - loss: 0.9585
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8874 - loss: 0.9319
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8874 - loss: 0.8903
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8874 - loss: 0.9161
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8978 - loss: 0.8683
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8978 - loss: 0.8449
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8770 - loss: 0.8277
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9082 - loss: 0.7801
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9328 - loss: 0.7724
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9328 - loss: 0.7500
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9120 - loss: 0.7461
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9120 - loss: 0.7246
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9470 - loss: 0.6911
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9366 - loss: 0.6951
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9470 - loss: 0.6711
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9262 - loss: 0.6719
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9262 - loss: 0.6463
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9366 - loss: 0.6481
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9366 - loss: 0.6079
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9366 - loss: 0.6085
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9366 - loss: 0.5817
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9366 - loss: 0.5691
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9366 - loss: 0.5610
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9470 - loss: 0.5496
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9366 - loss: 0.5491
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9262 - loss: 0.5359
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9470 - loss: 0.5115
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9366 - loss: 0.5131
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9366 - loss: 0.5014
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9470 - loss: 0.4820
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9470 - loss: 0.4689
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9470 - loss: 0.4653
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9262 - loss: 0.4796
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9262 - loss: 0.4552
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9262 - loss: 0.4471
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9470 - loss: 0.4360
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9366 - loss: 0.4308
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9612 - loss: 0.4103
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9612 - loss: 0.4085
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9508 - loss: 0.4146
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9612 - loss: 0.3943
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9754 - loss: 0.3846
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9858 - loss: 0.3794

# %%
#After training, we use a starting sequence to generate new text character-by-character.

start_seq = "This is GeeksforGeeks a"
generated_text = start_seq

for i in range(50):
    x = np.array([[char_to_index[char] for char in generated_text[-seq_length:]]])
    x_one_hot = tf.one_hot(x, len(chars))
    prediction = model.predict(x_one_hot)
    next_index = np.argmax(prediction)
    next_char = index_to_char[next_index]
    generated_text += next_char

print("Generated Text:")
print(generated_text)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Generated Text:
# This is GeeksforGeeks a software training institutetrtatrtitrtetkt treitr

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import SGD, Adam, RMSprop

# Sample text corpus (you can replace this with a larger dataset)
text = "This is a simple text data for testing the text generation model."
chars = sorted(set(text))
char_to_index = {ch: i for i, ch in enumerate(chars)}
index_to_char = {i: ch for ch, i in char_to_index.items()}
vocab_size = len(chars)

# Prepare sequences
seq_length = 10
step = 1
input_seqs = []
target_chars = []

for i in range(0, len(text) - seq_length, step):
    input_seqs.append([char_to_index[ch] for ch in text[i:i+seq_length]])
    target_chars.append(char_to_index[text[i + seq_length]])

X = tf.one_hot(input_seqs, vocab_size)  # shape: (samples, seq_length, vocab_size)
y = tf.keras.utils.to_categorical(target_chars, num_classes=vocab_size)

# Function to build model
def build_model(optimizer):
    model = Sequential([
        LSTM(128, input_shape=(seq_length, vocab_size)),
        Dense(vocab_size, activation='softmax')
    ])
    model.compile(loss='categorical_crossentropy', optimizer=optimizer)
    return model

# Text generation function
def generate_text(model, start_seq, gen_length=100):
    input_seq = [char_to_index[c] for c in start_seq]

    for _ in range(gen_length):
        input_tensor = tf.one_hot([input_seq], vocab_size)
        preds = model.predict(input_tensor, verbose=0)[0]
        next_index = np.random.choice(len(chars), p=preds)
        next_char = index_to_char[next_index]
        print(next_char, end='')
        input_seq = input_seq[1:] + [next_index]

# Evaluating different optimizers
optimizers = {
    'SGD': SGD(learning_rate=0.1),
    'Adam': Adam(),
    'RMSprop': RMSprop()
}

start_seq = "This is a "

for name, optimizer in optimizers.items():
    print(f"\n\n--- Training with {name} Optimizer ---")
    model = build_model(optimizer)
    model.fit(X, y, batch_size=16, epochs=10, verbose=0)
    print(f"\nGenerated text using {name}:\n")
    generate_text(model, start_seq=start_seq, gen_length=200)
    print("\n" + "-"*60)
# Out:
# --- Training with SGD Optimizer ---
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Generated text using SGD:
#
# a.gteadst arge  drnismToTd xe gimaga  it gsfnf.hxndianifpTseffxtadteagdretltirontaodtt  m tf tlia g tt prosriioetexeof.ooemd tisxfa hidlrtil.Ta.lx.gssemats tfltxhildan ettsrgothntiatohx loTdeeehsehnno
# ------------------------------------------------------------
#
#
# --- Training with Adam Optimizer ---
#
# Generated text using Adam:
#
#  oeirptrttmepffmdtolgeiostmxdao grtta  li  mxottf grx tetgfssxg.tdogfo x mtem dfom.xt opea etexhttddnanmoetige m hhaittitggdt gao raheeaaxra trdtitdgss fpeaoitiphtTden pnittgnefoomoTgetngerxTeaan.mhl
# ------------------------------------------------------------
#
#
# --- Training with RMSprop Optimizer ---
#
# Generated text using RMSprop:
#
# fe.rn.ratet mtoosl Tasi.idllraphdeixrhltte oedtsetehtahftmrfno ehx ems  rn.prlntoa.en  sdile emhtr xi  hoeetxmrxsTethnen ndxlogt.slmsieodafoiog hdgsd.ht.n t l.istane tttgttt  e to.e h i asshgpat g exe
# ------------------------------------------------------------
